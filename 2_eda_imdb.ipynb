# %% [markdown]
# # Análisis exploratorio de una base de datos de películas
#
# Usa la base de datos `./data/imdb.csv`
#
#
# ### 1. Importar `pandas`, `matplotlib` y `numpy`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Leer la base de datos del archivo csv a pandas

# %%
df = pd.read_csv(r'C:\Users\Roxana Velasco\Documents\GitHub\limpieza_datos_y_eda\Estatal-Delitos-2015-2025_sep2025.csv', encoding="latin1")

# %% [markdown]
# ### 3. Mostrar las  primeras y últimas filas del dataframe. Hacerlo con el valor default y pasando como argumento el número entero de filas que se deseen inspeccionar.

# %%
df.head()
df.tail()
df.head(3)
df.tail(3)
# Out:
#         Año  Clave_Ent    Entidad  \
# 34493  2025         32  Zacatecas
# 34494  2025         32  Zacatecas
# 34495  2025         32  Zacatecas
#
#                                   Bien jurídico afectado  \
# 34493  Otros bienes jurídicos afectados (del fuero co...
# 34494  Otros bienes jurídicos afectados (del fuero co...
# 34495  Otros bienes jurídicos afectados (del fuero co...
#
#                                   Tipo de delito  \
# 34493  Delitos cometidos por servidores públicos
# 34494                                Electorales
# 34495              Otros delitos del Fuero Común
#
#                                Subtipo de delito  \
# 34493  Delitos cometidos por servidores públicos
# 34494                                Electorales
# 34495              Otros delitos del Fuero Común
#
#                                        Modalidad  Enero  Febrero  Marzo  \
# 34493  Delitos cometidos por servidores públicos     37       35     24
# 34494                                Electorales      8        3      1
# 34495              Otros delitos del Fuero Común    190      164    184
#
#        Abril  Mayo  Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  \
# 34493     40    30     32     34      25          20      NaN        NaN
# 34494      0     2      2      0       0           1      NaN        NaN
# 34495    172    98    103    107     113         134      NaN        NaN
#
#        Diciembre
# 34493        NaN
# 34494        NaN
# 34495        NaN

# %% [markdown]
# ### 4. Continúa inspeccionando el archivo viendo todas las columnas del dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34496 entries, 0 to 34495
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     34496 non-null  int64
#  1   Clave_Ent               34496 non-null  int64
#  2   Entidad                 34496 non-null  object
#  3   Bien jurídico afectado  34496 non-null  object
#  4   Tipo de delito          34496 non-null  object
#  5   Subtipo de delito       34496 non-null  object
#  6   Modalidad               34496 non-null  object
#  7   Enero                   34496 non-null  int64
#  8   Febrero                 34496 non-null  int64
#  9   Marzo                   34496 non-null  int64
#  10  Abril                   34496 non-null  int64
#  11  Mayo                    34496 non-null  int64
#  12  Junio                   34496 non-null  int64
#  13  Julio                   34496 non-null  int64
#  14  Agosto                  34496 non-null  int64
#  15  Septiembre              34496 non-null  int64
#  16  Octubre                 31360 non-null  float64
#  17  Noviembre               31360 non-null  float64
#  18  Diciembre               31360 non-null  float64
# dtypes: float64(3), int64(11), object(5)
# memory usage: 5.0+ MB

# %%
df.columns
# Out:
# Index(['Año', 'Clave_Ent', 'Entidad', 'Bien jurídico afectado',
#        'Tipo de delito', 'Subtipo de delito', 'Modalidad', 'Enero', 'Febrero',
#        'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre',
#        'Octubre', 'Noviembre', 'Diciembre'],
#       dtype='object')

# %% [markdown]
# ### 5. Imprime los primeros valores de la variable `Rank`

# %% [markdown]
# No existe la variable Rank

# %% [markdown]
# ### 6. Demuestra que es mejor tener nombres de columnas sin espacios (notación corchetes y notación punto-variable).

# %% [markdown]
# Es mejor por que así puedes usar la vairable directamente, en vez de ponerla entre corchetes. Por ejemplo: 'Bien jurídico afectado'

# %% [markdown]
# ### 7. Renombra las columnas que tengan espacios

# %%
df.rename(columns={
    "Bien jurídico afectado": "bien_jur_afect",
    "Tipo de delito": "tipo_de_delito",
    "Subtipo de delito": "subtipo_de_delito"}, inplace=True)

# %%
df.columns
# Out:
# Index(['Año', 'Clave_Ent', 'Entidad', 'bien_jur_afect', 'tipo_de_delito',
#        'subtipo_de_delito', 'Modalidad', 'Enero', 'Febrero', 'Marzo', 'Abril',
#        'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre',
#        'Noviembre', 'Diciembre'],
#       dtype='object')

# %% [markdown]
# ### 8. Utiliza tus nuevas columnas sin espacios :)

# %%
df.bien_jur_afect.count()
# Out:
# np.int64(34496)

# %% [markdown]
# ### 9. Visualiza la info de todo tu dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34496 entries, 0 to 34495
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Año                34496 non-null  int64
#  1   Clave_Ent          34496 non-null  int64
#  2   Entidad            34496 non-null  object
#  3   bien_jur_afect     34496 non-null  object
#  4   tipo_de_delito     34496 non-null  object
#  5   subtipo_de_delito  34496 non-null  object
#  6   Modalidad          34496 non-null  object
#  7   Enero              34496 non-null  int64
#  8   Febrero            34496 non-null  int64
#  9   Marzo              34496 non-null  int64
#  10  Abril              34496 non-null  int64
#  11  Mayo               34496 non-null  int64
#  12  Junio              34496 non-null  int64
#  13  Julio              34496 non-null  int64
#  14  Agosto             34496 non-null  int64
#  15  Septiembre         34496 non-null  int64
#  16  Octubre            31360 non-null  float64
#  17  Noviembre          31360 non-null  float64
#  18  Diciembre          31360 non-null  float64
# dtypes: float64(3), int64(11), object(5)
# memory usage: 5.0+ MB

# %% [markdown]
# ### 10. Inspecciona si hay columnas que tengan valores `NA`

# %%
df.isna().sum()
# Out:
# Año                     0
# Clave_Ent               0
# Entidad                 0
# bien_jur_afect          0
# tipo_de_delito          0
# subtipo_de_delito       0
# Modalidad               0
# Enero                   0
# Febrero                 0
# Marzo                   0
# Abril                   0
# Mayo                    0
# Junio                   0
# Julio                   0
# Agosto                  0
# Septiembre              0
# Octubre              3136
# Noviembre            3136
# Diciembre            3136
# dtype: int64

# %% [markdown]
# ### 11. Imprime el número total de valores NA que haya en cada columna. Hazlo primero para la columna `Metascore` y después utiliza un ciclo for para hacerlo para todas las columnas

# %%
for col in df.columns:
    print(col, df[col].isna().sum())
# Out:
# Año 0
# Clave_Ent 0
# Entidad 0
# bien_jur_afect 0
# tipo_de_delito 0
# subtipo_de_delito 0
# Modalidad 0
# Enero 0
# Febrero 0
# Marzo 0
# Abril 0
# Mayo 0
# Junio 0
# Julio 0
# Agosto 0
# Septiembre 0
# Octubre 3136
# Noviembre 3136
# Diciembre 3136

# %% [markdown]
# ### 12. Usa la magia de `dropna()`

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### 13. Vuelve a ver la info del dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31360 entries, 0 to 31359
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Año                31360 non-null  int64
#  1   Clave_Ent          31360 non-null  int64
#  2   Entidad            31360 non-null  object
#  3   bien_jur_afect     31360 non-null  object
#  4   tipo_de_delito     31360 non-null  object
#  5   subtipo_de_delito  31360 non-null  object
#  6   Modalidad          31360 non-null  object
#  7   Enero              31360 non-null  int64
#  8   Febrero            31360 non-null  int64
#  9   Marzo              31360 non-null  int64
#  10  Abril              31360 non-null  int64
#  11  Mayo               31360 non-null  int64
#  12  Junio              31360 non-null  int64
#  13  Julio              31360 non-null  int64
#  14  Agosto             31360 non-null  int64
#  15  Septiembre         31360 non-null  int64
#  16  Octubre            31360 non-null  float64
#  17  Noviembre          31360 non-null  float64
#  18  Diciembre          31360 non-null  float64
# dtypes: float64(3), int64(11), object(5)
# memory usage: 4.8+ MB

# %% [markdown]
# ### 14. Genera estadísticos descriptivos con el método `describe()`

# %%
df.describe()
# Out:
#                 Año    Clave_Ent         Enero       Febrero         Marzo  \
# count  31360.000000  31360.00000  31360.000000  31360.000000  31360.000000
# mean    2019.500000     16.50000     49.448693     49.386161     54.860810
# std        2.872327      9.23324    190.467962    193.413413    215.622814
# min     2015.000000      1.00000      0.000000      0.000000      0.000000
# 25%     2017.000000      8.75000      0.000000      0.000000      0.000000
# 50%     2019.500000     16.50000      1.000000      2.000000      2.000000
# 75%     2022.000000     24.25000     25.000000     25.000000     28.000000
# max     2024.000000     32.00000   7565.000000   7888.000000   8418.000000
#
#               Abril          Mayo         Junio         Julio        Agosto  \
# count  31360.000000  31360.000000  31360.000000  31360.000000  31360.000000
# mean      51.391008     54.328827     53.691645     52.701722     54.039668
# std      199.999257    212.639108    207.026278    200.997995    208.404789
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      2.000000      2.000000      1.000000      2.000000
# 75%       25.000000     27.000000     27.000000     26.000000     27.000000
# max     7916.000000   7899.000000   7386.000000   7619.000000   7955.000000
#
#          Septiembre       Octubre     Noviembre     Diciembre
# count  31360.000000  31360.000000  31360.000000  31360.000000
# mean      52.873533     55.246365     51.528476     49.175957
# std      202.489260    213.245579    196.730439    190.961632
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        2.000000      2.000000      2.000000      1.000000
# 75%       27.000000     28.000000     26.000000     24.000000
# max     7805.000000   8421.000000   7750.000000   7851.000000

# %% [markdown]
# ### 15. Crea un histograma de la variable Metascore. Utiliza 10 cubetas

# %%
plt.hist(df['Clave_Ent'], bins=10)
# Out:
# (array([3920., 2940., 2940., 2940., 2940., 2940., 2940., 2940., 2940.,
#         3920.]),
#  array([ 1. ,  4.1,  7.2, 10.3, 13.4, 16.5, 19.6, 22.7, 25.8, 28.9, 32. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 16. Crea un histograma de la variable Rating. Utiliza 10 cubetas

# %%
plt.hist(df['Clave_Ent'], bins=10)
# Out:
# (array([3920., 2940., 2940., 2940., 2940., 2940., 2940., 2940., 2940.,
#         3920.]),
#  array([ 1. ,  4.1,  7.2, 10.3, 13.4, 16.5, 19.6, 22.7, 25.8, 28.9, 32. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 17. Vuelve a describir el dataframe y observa la media de la variable `Ratings`

# %%
np.mean(df.Clave_Ent)
# Out:
# np.float64(16.5)

# %% [markdown]
# ### 18. Calcula este promedio con Numpy y después con un método de Pandas

# %% [markdown]
# ### 19. Obten los valores únicos de la variable Rating y después ordénalos de menor a mayor

# %% [markdown]
# ### 20. Observa los ratings que te interesen y ahora filtra el dataframe con ese rating para ver cuáles son las películas con dicho rating

# %% [markdown]
# ### 21. Obten los valores únicos de la variable Rating y la frecuencia total de cada uno de estos valores. Posteriormente crea un nuevo dataframe con essos valores

# %% [markdown]
# ### 22. Ordena el nuevo dataframe por la variable `rating`

# %% [markdown]
# ### 23. Crea una gráfica de barras con este nuevo dataframe ordenado

# %% [markdown]
# ### 24. Crea la matriz de correlación del dataframe de películas

# %% [markdown]
# ### 25. Grafica la matriz de correlación utilizando `matshow()`
